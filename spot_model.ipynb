# %% [markdown]
# Sistem Özelliklerine bakıyorum.

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %% [markdown]
# Depolama Alanı Güncelliyorum.
#
# > Her eğitimden önce bu işlemi yapmalıyım.

# %%
# !apt-get update
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# ...

# %% [markdown]
# Adres Öğrenme

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# Darkneti zipten çıkarma
# Sağ tıklayıp yolu kopyala diyerek tırnak işareti içerisine yapıştırmalısınız.

# %%
# !unzip "/content/drive/My Drive/custom_spot_model/darknet.zip"
# Out:
# Archive:  /content/drive/My Drive/custom_spot_model/darknet.zip
#    creating: darknet/.circleci/
#   inflating: darknet/.circleci/config.yml
#   inflating: darknet/.gitignore
#   inflating: darknet/.travis.yml
#    creating: darknet/3rdparty/
#    creating: darknet/3rdparty/pthreads/
#    creating: darknet/3rdparty/pthreads/bin/
#   inflating: darknet/3rdparty/pthreads/bin/pthreadGC2.dll
#   inflating: darknet/3rdparty/pthreads/bin/pthreadVC2.dll
#    creating: darknet/3rdparty/pthreads/include/
#   inflating: darknet/3rdparty/pthreads/include/pthread.h
#   inflating: darknet/3rdparty/pthreads/include/sched.h
#   inflating: darknet/3rdparty/pthreads/include/semaphore.h
#    creating: darknet/3rdparty/pthreads/lib/
#   inflating: darknet/3rdparty/pthreads/lib/libpthreadGC2.a
#   inflating: darknet/3rdparty/pthreads/lib/pthreadVC2.lib
#    creating: darknet/3rdparty/stb/
#    creating: darknet/3rdparty/stb/include/
#   inflating: darknet/3rdparty/stb/include/stb_image.h
# ...

# %% [markdown]
# Adres Ayarlama

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# dos2unix İndirme

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 0s (4,260 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %% [markdown]
# dosyaları unixe çevirme
# Dosyaları linuxun anlayabileceği biçime çevirmem gerekiyor

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./build/darknet/x64/data/person.jpg
# dos2unix: converting file ./build/darknet/x64/data/combine9k.data to Unix format...
# dos2unix: converting file ./build/darknet/x64/data/goal.txt to Unix format...
# dos2unix: Binary symbol 0x02 found at line 1
# dos2unix: Skipping binary file ./build/darknet/x64/data/dog.jpg
# dos2unix: converting file ./build/darknet/x64/data/coco.names to Unix format...
# dos2unix: converting file ./build/darknet/x64/data/imagenet.shortnames.list to Unix format...
# dos2unix: converting file ./build/darknet/x64/data/openimages.names to Unix format...
# dos2unix: converting file ./build/darknet/x64/data/coco9k.map to Unix format...
# dos2unix: converting file ./build/darknet/x64/data/voc.data to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./build/darknet/x64/data/horses.jpg
# ...

# %% [markdown]
# İzin
# Darknet dosyalarını çalıştırabilmek için izin alıyorum

# %%
# !chmod +x /content/darknet

# %% [markdown]
# Dosyaları Çalıştırıyorum

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# Darknet testi (bir resim üzerinde)

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/dog.jpg
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# Dosya Silme
# Backup dosyasını siliyorum.

# %%
# !rm /content/darknet/backup -r

# %% [markdown]
# Driveda sağ tıklayıp yeni klasör diyip Spot_weights isimli bir dosya oluşturuyorum. Sonrasında bu dosyanın içine backup isimli yeni bir klasör ekliyorum. Sonrasında
# Drive backup bağlantısını aşağıdaki gibi yapıyorum.

# %%
# !ln -s /content/drive/"My Drive"/spot_weights/backup /content/darknet

# %% [markdown]
# Adresimi kontrol ediyorum

# %%
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# Eğitime başlama
# Aşağıdaki kodla eğitim işlemimi yapıyorum zaman alacak bekleyin :)

# %%
# !./darknet detector train spot_data/spot.data spot_yolov4.cfg yolov4.conv.137 -map -dont_show
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Eğitimimi Tamamladım

# %% [markdown]
# Şimdi sonuçları bir video üzerinde deneyeceğim.
# Bunun için tespit etmek istediğim nesnenin bulunduğu bir videoyu drive'a yüklüyorum ve devam ediyorum.

# %%
# !./darknet detector demo /content/darknet/spot_data/spot.data /content/darknet/spot_yolov4.cfg /content/drive/"My Drive"/spot_weights/backup/spot_yolov4_2000.weights -dont_show /content/drive/"My Drive"/spot.mp4 -i 0 -out_filename results.avi
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#
# FPS:39.4 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
#
# FPS:39.2 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
#
# FPS:38.9 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
# Spot: 52%
#
# FPS:38.7 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
# Spot: 58%
#
# FPS:40.0 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
#
# FPS:39.6 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
# Spot: 39%
#
# FPS:39.6 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 99%
#
# FPS:40.7 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 100%
#
# FPS:40.2 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 99%
#
# FPS:38.7 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 99%
#
# FPS:38.0 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 99%
# Spot: 99%
#
# FPS:37.8 	 AVG_FPS:40.1
#
#  cvWriteFrame
# Objects:
#
# Spot: 99%
# Spot: 99%
#
# FPS:37.7 	 AVG_FPS:40.1
#
# ...

# %% [markdown]
# Videomda nesne tespiti yaptım

# %% [markdown]
# Şimdi nesne tespiti yaptığım videomun son halin bilgisayarıma indireceğim.

# %% [markdown]
# İndirmek için aşağıdaki kodları yazıyorum.

# %%
def download(path):
  from google.colab import files
  files.download(path)

# %%
download('results.avi')

# %% [markdown]
# Dosyam indi :)
